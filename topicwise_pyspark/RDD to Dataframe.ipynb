# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

rdd = spark.sparkContext.parallelize([
    (1, "Bhushan", 70000),
    (2, "Ravi", 45000),
    (3, "Rahul", 80000)
])

df = spark.createDataFrame(rdd, ["id", "name", "salary"])
df.show()

# %%
df = rdd.toDF(["id", "name", "salary"])
df.show()

# %%
from pyspark.sql.types import *

schema = StructType([
    StructField("id", IntegerType(), True),
    StructField("name", StringType(), True),
    StructField("salary", IntegerType(), True)
])

df = spark.createDataFrame(rdd, schema)
df.show()

# %%
from pyspark.sql import Row

rdd = spark.sparkContext.parallelize([
    Row(id =1, name = "Bhushan", salary = 80000),
    Row(id=2, name = "Neha", salary = 45000)
])

df = spark.createDataFrame(rdd)
df.show()

# %%
#This code will not run because RDD not supported in Serverless.
# Options : Use Dataframe or Use Single-User or Classic Cluster
